# %%
from cropengine.site import WOFOSTSiteParametersProvider

# %%
site_param_provider = WOFOSTSiteParametersProvider("Wofost72_PP", **{"WAV": 10})

# %%
dict(site_param_provider)
# Out:
# {'WAV': 10.0,
#  'IFUNRN': 0,
#  'NOTINF': 0.0,
#  'SSMAX': 0.0,
#  'SMLIM': 0.4,
#  'SSI': 0.0}

# %%
site_param_provider.param_metadata.keys()
# Out:
# dict_keys(['WAV', 'IFUNRN', 'NOTINF', 'SSMAX', 'SMLIM', 'SSI'])
