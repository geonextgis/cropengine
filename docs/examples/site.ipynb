# %%
from cropengine.site import WOFOSTSiteParametersProvider

# %%
site_param_provider = WOFOSTSiteParametersProvider('WOFOST72', **{'WAV': 10})

# %%
dict(site_param_provider)
# Out:
# {'IFUNRN': 0,
#  'SMLIM': 0.4,
#  'WAV': 10.0,
#  'SSI': 0.0,
#  'NOTINF': 0.0,
#  'SSMAX': 0.0}

# %%
site_param_provider.param_metadata
# Out:
# {'IFUNRN': {'default': 0,
#   'range': [0, 1],
#   'type': 'int',
#   'description': 'Indicates whether non-infiltrating fraction of rain is a function of storm size (1) or not (0).',
#   'unit': '-'},
#  'SMLIM': {'default': 0.4,
#   'range': [0.0, 1.0],
#   'type': 'float',
#   'description': 'Initial maximum moisture content in initial rooting depth zone.',
#   'unit': '-'},
#  'WAV': {'default': None,
#   'range': [0.0, 100.0],
#   'type': 'float',
#   'description': 'Initial amount of water in total soil profile.',
#   'unit': 'cm'},
#  'SSI': {'default': 0.0,
#   'range': [0.0, 100.0],
#   'type': 'float',
#   'description': 'Initial depth of water stored on the surface.',
#   'unit': 'cm'},
#  'NOTINF': {'default': 0.0,
#   'range': [0.0, 1.0],
#   'type': 'float',
#   'description': 'Maximum fraction of rain not-infiltrating into the soil.',
#   'unit': '-'},
#  'SSMAX': {'default': 0.0,
#   'range': [0.0, 100.0],
#   'type': 'float',
# ...
