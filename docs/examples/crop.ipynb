# %%
from cropengine.crop import WOFOSTCropParametersProvider

# %%
crop_params = WOFOSTCropParametersProvider(
    crop_name="wheat", variety_name="Winter_wheat_101"
)

# %%
crop_params.keys()

# %%
crop_params.

# %%
from pcse.input import YAMLCropDataProvider

c_d = YAMLCropDataProvider()

# %%
c_d.get_crops_varieties()

# %%
crop_params.get_crops_varieties()
