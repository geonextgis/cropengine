# %%
from cropengine.soil import IsricSoilDataProvider, WOFOSTSoilParameterProvider, GEEIsricSoilDataProvider

# %%
soil_data_provider = GEEIsricSoilDataProvider(
    latitude=52.53,
    longitude=14.12,
    depths=["0-5cm"]
)
soil_data = soil_data_provider.get_data()
# Out:
# Fetching GEE Soil data for 52.53, 14.12...

# %%
soil_data
# Out:
#    latitude  longitude  property  depth metric  value        unit  \
# 0     52.53      14.12      bdod  0-5cm   mean    137      cg/cm³
# 1     52.53      14.12       cec  0-5cm   mean    282  mmol(c)/kg
# 2     52.53      14.12      cfvo  0-5cm   mean     57     cm³/dm³
# 3     52.53      14.12      clay  0-5cm   mean     97        g/kg
# 4     52.53      14.12  nitrogen  0-5cm   mean   6487       cg/kg
# 5     52.53      14.12       ocd  0-5cm   mean    377       hg/m³
# 6     52.53      14.12     phh2o  0-5cm   mean     63       pH*10
# 7     52.53      14.12      sand  0-5cm   mean    757        g/kg
# 8     52.53      14.12      silt  0-5cm   mean    145        g/kg
# 9     52.53      14.12       soc  0-5cm   mean    484       dg/kg
#
#    transformed_value transformed_unit
# 0               1.37           kg/dm³
# 1              28.20       cmol(c)/kg
# 2               5.70       cm³/100cm³
# 3               9.70                %
# 4              64.87             g/kg
# 5              37.70            kg/m³
# 6               6.30               pH
# 7              75.70                %
# 8              14.50                %
# 9              48.40             g/kg

# %%
soil_params_provider = WOFOSTSoilParameterProvider(soil_data)

# %%
soil_params_provider.param_metadata
# Out:
# [{'parameter': 'SMFCF',
#   'description': 'Field capacity of the soil',
#   'unit': '-',
#   'value': 0.3},
#  {'parameter': 'SM0',
#   'description': 'Porosity of the soil',
#   'unit': '-',
#   'value': 0.483},
#  {'parameter': 'SMW',
#   'description': 'Wilting point of the soil',
#   'unit': '-',
#   'value': 0.1},
#  {'parameter': 'CRAIRC',
#   'description': 'Critical air content for aeration for root system',
#   'unit': 'm3 air m-3 soil',
#   'value': 0.06},
#  {'parameter': 'SOPE',
#   'description': 'Maximum percolation rate root zone',
#   'unit': 'cm/day',
#   'value': 46.98},
#  {'parameter': 'KSUB',
#   'description': 'Maximum percolation rate subsoil',
#   'unit': 'cm/day',
#   'value': 46.98},
#  {'parameter': 'RDMSOL',
#   'description': 'Maximum soil rootable depth',
#   'unit': 'cm',
#   'value': 120},
#  {'parameter': 'IFUNRN',
#   'description': 'Indicates whether non-infiltrating fraction of rain is a function of storm size (1) or not (0)',
#   'unit': '-',
#   'value': None},
#  {'parameter': 'SSMAX',
#   'description': 'Maximum surface storage',
#   'unit': 'cm',
#   'value': None},
#  {'parameter': 'SSI',
#   'description': 'Initial surface storage',
#   'unit': 'cm',
#   'value': None},
#  {'parameter': 'WAV',
#   'description': 'Initial amount of water in the soil',
#   'unit': 'cm',
#   'value': None},
#  {'parameter': 'NOTINF',
#   'description': 'Maximum fraction of rain not-infiltrating into the soil',
#   'unit': '-',
#   'value': None},
#  {'parameter': 'SMLIM',
#   'description': 'Maximum soil moisture content of top soil layer',
#   'unit': 'cm3/cm3',
#   'value': None},
#  {'parameter': 'SMfromPF',
#   'description': 'Table function describing the soil moisture content as a function of pF',
#   'unit': 'm3 water m-3 soil',
#   'value': None},
#  {'parameter': 'CONDfromPF',
#   'description': 'Table function of the 10-base logarithm of the unsaturated hydraulic conductivity as a function of pF',
#   'unit': 'log10(cm water d-1)',
#   'value': None},
#  {'parameter': 'Thickness',
#   'description': 'Layer thickness',
#   'unit': 'cm',
#   'value': 5.0},
#  {'parameter': 'FSOMI',
#   'description': 'Initial fraction of soil organic matter in soil',
#   'unit': 'kg OM kg-1 soil',
#   'value': 0.0834},
#  {'parameter': 'CNRatioSOMI',
#   'description': 'Initial C:N ratio of soil organic matter',
#   'unit': 'kg C kg-1 N',
#   'value': 0.75},
#  {'parameter': 'RHOD',
#   'description': 'Bulk density of the soil',
#   'unit': 'g soil cm-3 soil',
#   'value': 1.37},
#  {'parameter': 'Soil_pH',
#   'description': 'pH of the soil layer',
#   'unit': '-',
#   'value': 6.3},
#  {'parameter': 'TMINACCU1',
#   'description': 'Upper critical minimum temperature for snow accumulation',
#   'unit': '°C',
#   'value': None},
#  {'parameter': 'TMINACCU2',
#   'description': 'Lower critical minimum temperature for snow accumulation',
#   'unit': '°C',
#   'value': None},
#  {'parameter': 'TMINCRIT',
#   'description': 'Critical minimum temperature for snow melt',
#   'unit': '°C',
#   'value': None},
#  {'parameter': 'TMAXCRIT',
#   'description': 'Critical maximum temperature for snow melt',
#   'unit': '°C',
#   'value': None},
#  {'parameter': 'RMELT',
#   'description': 'Melting rate per day per degree Celsius above the critical minimum temperature',
#   'unit': 'cm/°C/day',
#   'value': None},
#  {'parameter': 'SCTHRESHOLD',
#   'description': 'Snow water equivalent above which the sublimation is taken into account',
#   'unit': 'cm',
#   'value': None},
#  {'parameter': 'SNOWDENSITY',
#   'description': 'Density of snow',
#   'unit': 'cm/cm',
#   'value': None},
#  {'parameter': 'SWEDEPTHI',
#   'description': 'Initial depth of layer of water present as snow on the soil surface',
#   'unit': 'cm',
#   'value': None},
#  {'parameter': 'NSOILBASE',
#   'description': 'Base soil supply of N available through mineralisation',
#   'unit': 'kg/ha',
#   'value': None},
#  {'parameter': 'NSOILBASE_FR',
#   'description': 'Fraction of base soil N that comes available every day',
#   'unit': 'fraction/day',
#   'value': None},
#  {'parameter': 'NAVAILI',
#   'description': 'Initial N available in the N pool',
#   'unit': 'kg/ha',
#   'value': None},
#  {'parameter': 'BG_N_SUPPLY',
#   'description': 'Background supply of N through atmospheric deposition',
#   'unit': 'kg/ha/day',
#   'value': None},
#  {'parameter': 'A0SOM',
#   'description': 'Initial age of soil organic material',
#   'unit': 'year',
#   'value': None},
#  {'parameter': 'CNRatioBio',
#   'description': 'C:N ratio of microbial biomass',
#   'unit': 'kg C kg-1 N',
#   'value': None},
#  {'parameter': 'FASDIS',
#   'description': 'Fraction of assimilation to dissimilation',
#   'unit': '-',
#   'value': None},
#  {'parameter': 'KDENIT_REF',
#   'description': 'Reference first order denitrification rate constant',
#   'unit': 'd-1',
#   'value': None},
#  {'parameter': 'KNIT_REF',
#   'description': 'Reference first order nitrification rate constant',
#   'unit': 'd-1',
#   'value': None},
#  {'parameter': 'KSORP',
#   'description': 'Sorption coefficient ammonium',
#   'unit': 'm3 water kg-1 soil',
#   'value': None},
#  {'parameter': 'MRCDIS',
#   'description': 'Michaelis Menten constant for response factor denitrification to soil respiration',
#   'unit': 'kg C m-2 d-1',
#   'value': None},
#  {'parameter': 'NO3ConcR',
#   'description': 'NO3-N concentration in rain water',
#   'unit': 'mg NO3-N L-1 water',
#   'value': None},
#  {'parameter': 'NH4ConcR',
#   'description': 'NH4-N concentration in rain water',
#   'unit': 'mg NH4+-N L-1 water',
#   'value': None},
#  {'parameter': 'NO3I',
#   'description': 'Initial amount of NO3-N',
#   'unit': 'kg NO3-N ha-1',
#   'value': None},
#  {'parameter': 'NH4I',
#   'description': 'Initial amount of NH4-N',
#   'unit': 'kg NH4+-N ha-1',
#   'value': None},
#  {'parameter': 'WFPS_CRIT',
#   'description': 'Critical water filled pore space fraction',
#   'unit': 'm3 water m-3 pore',
#   'value': None},
#  {'parameter': 'K0',
#   'description': 'Hydraulic conductivity of saturated soil',
#   'unit': 'cm/day',
#   'value': 46.98},
#  {'parameter': 'IVINF',
#   'description': 'Infiltration limiter',
#   'unit': '-',
#   'value': None}]

# %%
soil_params_provider.get_params()
# Out:
# {'SMFCF': 0.3,
#  'SM0': 0.483,
#  'SMW': 0.1,
#  'RDMSOL': 120,
#  'CRAIRC': 0.06,
#  'K0': 46.98,
#  'SOPE': 46.98,
#  'KSUB': 46.98,
#  'Soil_pH': 6.3,
#  'FSOMI': 0.0834,
#  'CNRatioSOMI': 0.75,
#  'RHOD': 1.37,
#  'Thickness': 5.0}
