# %%
from cropengine.soil import IsricSoilDataProvider, WOFOSTSoilParameterProvider

# %%
soil_data_provider = IsricSoilDataProvider(latitude=52.53, longitude=14.12, properties=[ "bdod", "cec", "cfvo", "clay", "nitrogen", "ocd", "ocs", "phh2o", "sand", "silt", "soc", "wv0010", "wv0033", "wv1500"], depths=['0-5cm'], values='mean')
soil_data = soil_data_provider.get_data()
print(soil_data.shape)
soil_data.head()
# Out:
# Fetching soil data for 52.53, 14.12...
# (13, 9)
#    latitude  longitude  property  depth metric  value        unit  \
# 0     52.53      14.12      bdod  0-5cm   mean    138      cg/cm³
# 1     52.53      14.12       cec  0-5cm   mean    282  mmol(c)/kg
# 2     52.53      14.12      cfvo  0-5cm   mean     57     cm³/dm³
# 3     52.53      14.12      clay  0-5cm   mean     97        g/kg
# 4     52.53      14.12  nitrogen  0-5cm   mean    649       cg/kg
#
#    transformed_value transformed_unit
# 0               1.38           kg/dm³
# 1              28.20       cmol(c)/kg
# 2               5.70       cm³/100cm³
# 3               9.70                %
# 4               6.49             g/kg

# %%
# Calculate soil parameters
calc = WOFOSTSoilParameterProvider(soil_data, **{'SSI': 10})
pcse_soil_params = calc.get_params()
print(pcse_soil_params)
# Out:
# {'SMFCF': 0.479, 'SM0': 0.479, 'SMW': 0.068, 'RDMSOL': 120, 'CRAIRC': 0.05, 'K0': 10.0, 'SOPE': 10.0, 'KSUB': 10.0, 'Soil_pH': 6.3, 'RHOD': 1.38, 'FSOMI': 0.092, 'CNRatioSOMI': 8.213, 'Thickness': 5.0, 'SMfromPF': [-1.0, 0.479, 1.0, 0.479, 1.3, 0.479, 1.491, 0.479, 2.0, 0.479, 2.4, 0.47, 2.7, 0.089, 3.4, 0.068, 4.204, 0.068, 6.0, 0.068], 'CONDfromPF': [-1.0, 1.672, 1.0, 1.672, 1.3, 1.672, 1.491, 1.672, 2.0, 1.672, 2.4, 1.634, 2.7, -1.953, 3.4, -15.0, 4.204, -15.0, 6.0, -15.0], 'SSI': 10}

# %%
calc.param_metadata
# Out:
# {'SMFCF': {'description': 'Field capacity of the soil', 'unit': '-'},
#  'SMO': {'description': 'Porosity of the soil', 'unit': '-'},
#  'SMW': {'description': 'Wilting point of the soil', 'unit': '-'},
#  'CRAIRC': {'description': 'Critical air content for aeration for root system',
#   'unit': 'm3 air m-3 soil'},
#  'SOPE': {'description': 'Maximum percolation rate root zone',
#   'unit': 'cm/day'},
#  'KSUB': {'description': 'Maximum percolation rate subsoil', 'unit': 'cm/day'},
#  'RDMSOL': {'description': 'Maximum soil rootable depth', 'unit': 'cm'},
#  'IFUNRN': {'description': 'Indicates whether non-infiltrating fraction of rain is a function of storm size (1) or not (0)',
#   'unit': '-'},
#  'SSMAX': {'description': 'Maximum surface storage', 'unit': 'cm'},
#  'SSI': {'description': 'Initial surface storage', 'unit': 'cm'},
#  'WAV': {'description': 'Initial amount of water in the soil', 'unit': 'cm'},
#  'NOTINF': {'description': 'Maximum fraction of rain not-infiltrating into the soil',
#   'unit': '-'},
#  'SMLIM': {'description': 'Maximum soil moisture content of top soil layer',
#   'unit': 'cm3/cm3'},
#  'SMfromPF': {'description': 'Table function describing the soil moisture content as a function of pF',
#   'unit': 'm3 water m-3 soil'},
#  'CONDfromPF': {'description': 'Table function of the 10-base logarithm of the unsaturated hydraulic conductivity as a function of pF',
#   'unit': 'log10(cm water d-1)'},
#  'Thickness': {'description': 'Layer thickness', 'unit': 'cm'},
#  'FSOMI': {'description': 'Initial fraction of soil organic matter in soil',
#   'unit': 'kg OM kg-1 soil'},
#  'CNRatioSOMI': {'description': 'Initial C:N ratio of soil organic matter',
#   'unit': 'kg C kg-1 N'},
#  'RHOD': {'description': 'Bulk density of the soil',
#   'unit': 'g soil cm-3 soil'},
#  'Soil_pH': {'description': 'pH of the soil layer', 'unit': '-'},
#  'TMINACCU1': {'description': 'Upper critical minimum temperature for snow accumulation',
#   'unit': '°C'},
#  'TMINACCU2': {'description': 'Lower critical minimum temperature for snow accumulation',
#   'unit': '°C'},
#  'TMINCRIT': {'description': 'Critical minimum temperature for snow melt',
#   'unit': '°C'},
#  'TMAXCRIT': {'description': 'Critical maximum temperature for snow melt',
#   'unit': '°C'},
#  'RMELT': {'description': 'Melting rate per day per degree Celsius above the critical minimum temperature',
#   'unit': 'cm/°C/day'},
#  'SCTHRESHOLD': {'description': 'Snow water equivalent above which the sublimation is taken into account',
#   'unit': 'cm'},
#  'SNOWDENSITY': {'description': 'Density of snow', 'unit': 'cm/cm'},
#  'SWEDEPTHI': {'description': 'Initial depth of layer of water present as snow on the soil surface',
#   'unit': 'cm'},
#  'NSOILBASE': {'description': 'Base soil supply of N available through mineralisation',
#   'unit': 'kg/ha'},
#  'NSOILBASE_FR': {'description': 'Fraction of base soil N that comes available every day',
#   'unit': 'fraction/day'},
#  'NAVAILI': {'description': 'Initial N available in the N pool',
#   'unit': 'kg/ha'},
#  'BG_N_SUPPLY': {'description': 'Background supply of N through atmospheric deposition',
#   'unit': 'kg/ha/day'},
#  'A0SOM': {'description': 'Initial age of soil organic material',
#   'unit': 'year'},
#  'CNRatioBio': {'description': 'C:N ratio of microbial biomass',
#   'unit': 'kg C kg-1 N'},
#  'FASDIS': {'description': 'Fraction of assimilation to dissimilation',
#   'unit': '-'},
#  'KDENIT_REF': {'description': 'Reference first order denitrification rate constant',
#   'unit': 'd-1'},
#  'KNIT_REF': {'description': 'Reference first order nitrification rate constant',
#   'unit': 'd-1'},
#  'KSORP': {'description': 'Sorption coefficient ammonium',
#   'unit': 'm3 water kg-1 soil'},
#  'MRCDIS': {'description': 'Michaelis Menten constant for response factor denitrification to soil respiration',
#   'unit': 'kg C m-2 d-1'},
#  'NO3ConcR': {'description': 'NO3-N concentration in rain water',
#   'unit': 'mg NO3-N L-1 water'},
#  'NH4ConcR': {'description': 'NH4-N concentration in rain water',
#   'unit': 'mg NH4+-N L-1 water'},
#  'NO3I': {'description': 'Initial amount of NO3-N', 'unit': 'kg NO3-N ha-1'},
#  'NH4I': {'description': 'Initial amount of NH4-N', 'unit': 'kg NH4+-N ha-1'},
#  'WFPS_CRIT': {'description': 'Critical water filled pore space fraction',
#   'unit': 'm3 water m-3 pore'},
#  'K0': {'description': 'Hydraulic conductivity of saturated soil',
#   'unit': 'cm/day'},
#  'IVINF': {'description': 'Infiltration limiter', 'unit': '-'}}
