# %% [markdown]
# <a href="https://githubtocolab.com/geonextgis/cropengine/blob/main/docs/examples/Run wofost (single location).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open in Colab"/></a>
#
# Uncomment the following line to install the latest version of [cropengine](https://geonextgis.github.io/cropengine) if needed.

# %%
# !pip install -U cropengine

# %% [markdown]
# ## Import libraries

# %%
import os
import pandas as pd
import seaborn as sns
from cropengine import WOFOSTCropSimulationRunner
from cropengine.agromanagement import WOFOSTAgroEventBuilder

# %% [markdown]
# ## User inputs

# %% [markdown]
# ## Instantiate crop simulation engine for WOFOST

# %%
# Define the model name
MODEL_NAME = "Wofost72_WLP_CWB"

# Initialize Engine
runner = WOFOSTCropSimulationRunner(
    model_name=MODEL_NAME, workspace_dir="test_output/location_workspace"
)

# %%
# Location
LATITUDE = 53.3721
LONGITUDE = 13.82299

# Crop Configuration
# Note: Use runner.get_..._options() to see valid values if unsure
models = runner.get_model_options()
crops = runner.get_crop_options(MODEL_NAME)
CROP_NAME = "sugarbeet"
varieties = runner.get_variety_options(MODEL_NAME, CROP_NAME)
CROP_VARIETY = "Sugarbeet_601"

# Timing
crop_start_end = runner.get_crop_start_end_options()
CAMPAIGN_START = "2006-01-01"
CROP_START = "2006-04-05"
CROP_START_TYPE = "emergence"
CROP_END_TYPE = "harvest"
CROP_END = "2006-10-20"
CAMPAIGN_END = "2007-01-01"
MAX_DURATION = 300

# %% [markdown]
# ## Create agromanagements with user inputs

# %%
agro_event_builder = WOFOSTAgroEventBuilder()

# Note: Use agro_event_builder.get_..._events_info() to see valid values if unsure
timed_events_info = agro_event_builder.get_timed_events_info()
state_events_info = agro_event_builder.get_state_events_info()

# Build timed events (irrigation)
irrigation_schedule = [
    {"event_date": "2006-05-25", "amount": 3.0, "efficiency": 0.7},
    {"event_date": "2006-06-30", "amount": 2.5, "efficiency": 0.7},
]

irrigation_events = agro_event_builder.create_timed_events(
    signal_type="irrigate", events_list=irrigation_schedule
)

# Build state Events (fertilization based on DVS)
nitrogen_schedule = [
    {"threshold": 0.3, "N_amount": 40, "N_recovery": 0.7},
    {"threshold": 0.6, "N_amount": 60, "N_recovery": 0.7},
    {"threshold": 1.12, "N_amount": 40, "N_recovery": 0.7},
]

nitrogen_events = agro_event_builder.create_state_events(
    signal_type="apply_n",
    state_var="DVS",
    zero_condition="rising",
    events_list=nitrogen_schedule,
)

# %% [markdown]
# ## Prepare system (must be implemented before running the simulation)

# %%
runner.prepare_system(
    latitude=LATITUDE,
    longitude=LONGITUDE,
    campaign_start=CAMPAIGN_START,
    campaign_end=CAMPAIGN_END,
    crop_start=CROP_START,
    crop_start_type=CROP_START_TYPE,
    crop_end_type=CROP_END_TYPE,
    crop_end=CROP_END,
    max_duration=MAX_DURATION,
    crop_name=CROP_NAME,
    variety_name=CROP_VARIETY,
    timed_events=[irrigation_events],
    state_events=[nitrogen_events],
    force_update=False,
    force_param_update=True,
    site_overrides={'WAV': 10}, # Extra site params can be passed as overrides
)
# Out:
# [PREP] Preparing workspace: test_output/location_workspace
# [PREP] Using existing Agromanagement config.
# [PREP] System Ready.

# %% [markdown]
# ## Get the parameters table to be displayed in the dashboard

# %% [markdown]
# ### Soil parameters

# %%
soil_params = pd.read_csv(
    runner.files["soil_params"]
)  # To be displayed in the dashboard's 'soil parameters' table
print(soil_params.shape)
soil_params.head()
# Out:
# (46, 4)
#      parameter                                        description  \
# 0        A0SOM               Initial age of soil organic material
# 1  BG_N_SUPPLY  Background supply of N through atmospheric dep...
# 2   CNRatioBio                     C:N ratio of microbial biomass
# 3  CNRatioSOMI           Initial C:N ratio of soil organic matter
# 4   CONDfromPF  Table function of the 10-base logarithm of the...
#
#                   unit  value
# 0                 year    NaN
# 1            kg/ha/day    NaN
# 2          kg C kg-1 N    NaN
# 3          kg C kg-1 N   0.98
# 4  log10(cm water d-1)    NaN

# %%
site_params = pd.read_csv(
    runner.files["site_params"]
)  # To be displayed in the dashboard's 'site parameters' table
print(site_params.shape)
site_params.head()
# Out:
# (6, 8)
#   parameter  required  value  default         range   type  \
# 0    IFUNRN     False    0.0      0.0        [0, 1]    int
# 1    NOTINF     False    0.0      0.0    [0.0, 1.0]  float
# 2     SMLIM     False    0.4      0.4    [0.0, 1.0]  float
# 3       SSI     False    0.0      0.0  [0.0, 100.0]  float
# 4     SSMAX     False    0.0      0.0  [0.0, 100.0]  float
#
#                                          description unit
# 0  Indicates whether non-infiltrating fraction of...    -
# 1  Maximum fraction of rain not-infiltrating into...    -
# 2  Initial maximum moisture content in initial ro...    -
# 3      Initial depth of water stored on the surface.   cm
# 4  Maximum depth of water that can be stored on t...   cm

# %%
crop_params = pd.read_csv(
    runner.files["crop_params"]
)  # To be displayed in the dashboard's 'crop parameters' table
print(crop_params.shape)
crop_params.head()
# Out:
# (94, 5)
#    parameter                                        description  \
# 0     AMAXTB  maximum leaf CO2 assimilation rate as function...
# 1       CFET               correction factor transpiration rate
# 2  CO2AMAXTB  multiplication factor for AMAX to account for ...
# 3   CO2EFFTB  multiplication factor for EFF to account for a...
# 4   CO2TRATB  multiplication factor for maximum transpiratio...
#
#                     unit  required  \
# 0  ['-', 'kg.ha-1.hr-1']     False
# 1                      -     False
# 2           ['PPM', '-']     False
# 3           ['PPM', '-']     False
# 4           ['PPM', '-']     False
#
#                                                value
# 0  [0.0, 22.5, 1.0, 45.0, 1.13, 45.0, 1.8, 36.0, ...
# 1                                                1.0
# 2  [40.0, 0.0, 360.0, 1.0, 720.0, 1.6, 1000.0, 1....
# 3  [40.0, 0.0, 360.0, 1.0, 720.0, 1.11, 1000.0, 1...
# 4  [40.0, 0.0, 360.0, 1.0, 720.0, 0.9, 1000.0, 0....

# %% [markdown]
# ## Run the Simulation

# %%
simulation_output = runner.run_simulation(
    soil_overrides=None,  # Pass the user-edited soil parameters in a dictionary
    site_overrides=None,  # Pass the user-edited site parameters in a dictionary
    crop_overrides=None,  # Pass the user-edited crop parameters in a dictionary
    agro_file_path=None,  # Pass the user-uploaded agro_file_path if any.
)

# Set day as index
simulation_output = simulation_output.set_index("day")
print(simulation_output.shape)
simulation_output.head()
# Out:
# [RUN] Initializing Wofost72_WLP_CWB in test_output/location_workspace...
# (366, 12)
#             DVS  LAI  TAGP  TWSO  TWLV  TWST  TWRT  TRA  RD       SM    WWLOW  \
# day
# 2006-01-01  NaN  NaN   NaN   NaN   NaN   NaN   NaN  NaN NaN  0.40000  42.0000
# 2006-01-02  NaN  NaN   NaN   NaN   NaN   NaN   NaN  NaN NaN  0.31555  36.1555
# 2006-01-03  NaN  NaN   NaN   NaN   NaN   NaN   NaN  NaN NaN  0.30077  36.0077
# 2006-01-04  NaN  NaN   NaN   NaN   NaN   NaN   NaN  NaN NaN  0.31455  36.1455
# 2006-01-05  NaN  NaN   NaN   NaN   NaN   NaN   NaN  NaN NaN  0.30721  36.0721
#
#             RFTRA
# day
# 2006-01-01    NaN
# 2006-01-02    NaN
# 2006-01-03    NaN
# 2006-01-04    NaN
# 2006-01-05    NaN

# %% [markdown]
# ## Plot the simulation output

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
import math

# Variables
cols = 2
n_vars = len(simulation_output.columns)
rows = math.ceil(n_vars / cols)

# Use a categorical color palette large enough
palette = sns.color_palette("tab20", n_vars)

fig, axes = plt.subplots(rows, cols, figsize=(14, 2 * rows), sharex=True)
axes = np.array(axes).reshape(-1)

for i, var in enumerate(simulation_output.columns):
    sns.lineplot(
        x=simulation_output.index,
        y=simulation_output[var],
        ax=axes[i],
        color=palette[i],
    )

# Hide unused axes
for j in range(i + 1, len(axes)):
    axes[j].axis("off")

plt.tight_layout()
plt.show()

# %%
pd.DataFrame(runner.get_model_options())
# Out:
#                            id  \
# 0          Wofost72_Phenology
# 1                 Wofost72_PP
# 2            Wofost72_WLP_CWB
# 3                 Wofost73_PP
# 4            Wofost73_WLP_CWB
# 5           Wofost73_WLP_MLWB
# 6                 Wofost81_PP
# 7            Wofost81_WLP_CWB
# 8           Wofost81_WLP_MLWB
# 9       Wofost81_NWLP_CWB_CNB
# 10     Wofost81_NWLP_MLWB_CNB
# 11  Wofost81_NWLP_MLWB_SNOMIN
#
#                                                  name  \
# 0                         WOFOST 7.2 (Phenology Only)
# 1                   WOFOST 7.2 (Potential Production)
# 2                          WOFOST 7.2 (Water-Limited)
# 3                   WOFOST 7.3 (Potential Production)
# 4                 WOFOST 7.3 (Water-Limited, Classic)
# 5             WOFOST 7.3 (Water-Limited, Multi-Layer)
# 6                   WOFOST 8.1 (Potential Production)
# 7                 WOFOST 8.1 (Water-Limited, Classic)
# 8             WOFOST 8.1 (Water-Limited, Multi-Layer)
# 9             WOFOST 8.1 (Water & N Limited, Classic)
# 10  WOFOST 8.1 (Water & N Limited, Multi-Layer/Cla...
# 11             WOFOST 8.1 (Water & N Limited, SNOMIN)
#
#                                           description  \
# 0   Simulates only the phenological development st...
# 1   Simulates crop growth under potential producti...
# 2   Simulates crop growth limited by water availab...
# 3   Includes atmospheric CO2 response and biomass ...
# 4   Includes CO2 response and biomass reallocation...
# 5   Includes CO2 response and biomass reallocation...
# 6   Includes full crop N dynamics under potential ...
# 7   Includes full crop N dynamics under water-limi...
# 8   Includes full crop N dynamics under water-limi...
# 9   Simulates water and nitrogen limited growth us...
# 10  Simulates water and nitrogen limited growth us...
# 11  Simulates water and nitrogen limited growth us...
#
#               production_level water_balance nutrient_balance
# 0                    Phenology           N/A              N/A
# 1                    Potential           N/A              N/A
# 2                Water-limited       Classic              N/A
# 3                    Potential           N/A              N/A
# 4                Water-limited       Classic              N/A
# 5                Water-limited   Multi-layer              N/A
# 6                    Potential           N/A              N/A
# 7                Water-limited       Classic              N/A
# 8                Water-limited   Multi-layer              N/A
# 9   Water and Nitrogen limited       Classic          Classic
# 10  Water and Nitrogen limited   Multi-layer          Classic
# 11  Water and Nitrogen limited   Multi-layer           SNOMIN

# %% [markdown]
# - Wofost72_Phenology: Done
# - Wofost72_PP: Done
# - Wofost72_WLP_CWB: Done
# - Wofost73_PP: Done
# - Wofost73_WLP_CWB: Done
